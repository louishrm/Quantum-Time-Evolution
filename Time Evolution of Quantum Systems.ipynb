# %% [markdown]
# # Time Dependent Schrödinger Equation
# In the last video, we saw how to solve the time independent Schrödinger equation for the infinite square well numerically. Now, we're going to see how we can find the time evolution of a quantum system. The time dependent Schrödinger equation is:
#
# $$ i \hbar \frac{\partial \Psi}{\partial t} = \hat H \Psi(x,t)$$
#
# This can be solved using the separation of variables technique: $\Psi(x,t) = X(x) \tau(t)$. Using this, we see that $\tau(t) = \exp \left( -\frac{i E t}{\hbar} \right)$. So a general state, $\Psi(x,t)$ can be written as a linear combination of the eigenstates of the Hamiltonian:
#
# $$\Psi(x,t) = \sum_j a_j \psi_j(x) \exp \left( -\frac{i E_j t}{\hbar} \right)$$
#
# Where the coefficients can be found by integrating if we know the initial state of the system: $$a_j = \int \Psi(x,0)^{\star} \psi_j(x) dx.$$
#
# In this example, suppose we have an electron of mass $m$ in an infinite square well of length $L$. At the time $t=0$, the electron is in the state:
#
# $$\Psi(x,0) = \begin{cases} Ax, & 0 \leq x \leq L/2 \\ A(2-x), & L/2 < x \leq L \end{cases}$$
#
# We can first start by building a Python function returns the original state, ensuring it is properly normalised.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#grid
N = 500
L = 2
x = np.linspace(0,L,N+1)
Delta_x = x[1]-x[0]

#constants 
hbar = 1
m =1

# %%
def integral(f, axis=0):
    
    return np.sum(f*Delta_x, axis=axis)

def psi0(x):
    
    f = np.zeros(len(x))
    l = len(x)
    f[:l//2+1] = x[:l//2+1]
    f[l//2+1:] = 2-x[l//2+1:]
    
    A = integral(f**2)
    return f/np.sqrt(A)
    
plt.plot(x[1:-1], psi0(x[1:-1]))

psi0(x[1:-1])
# Out:
# array([0.00489896, 0.00979792, 0.01469688, 0.01959584, 0.0244948 ,
#        0.02939376, 0.03429272, 0.03919168, 0.04409064, 0.0489896 ,
#        0.05388856, 0.05878752, 0.06368648, 0.06858544, 0.0734844 ,
#        0.07838336, 0.08328232, 0.08818128, 0.09308024, 0.0979792 ,
#        0.10287816, 0.10777712, 0.11267608, 0.11757504, 0.122474  ,
#        0.12737296, 0.13227192, 0.13717088, 0.14206984, 0.1469688 ,
#        0.15186776, 0.15676672, 0.16166568, 0.16656464, 0.1714636 ,
#        0.17636256, 0.18126152, 0.18616048, 0.19105944, 0.1959584 ,
#        0.20085736, 0.20575632, 0.21065528, 0.21555424, 0.2204532 ,
#        0.22535215, 0.23025111, 0.23515007, 0.24004903, 0.24494799,
#        0.24984695, 0.25474591, 0.25964487, 0.26454383, 0.26944279,
#        0.27434175, 0.27924071, 0.28413967, 0.28903863, 0.29393759,
#        0.29883655, 0.30373551, 0.30863447, 0.31353343, 0.31843239,
#        0.32333135, 0.32823031, 0.33312927, 0.33802823, 0.34292719,
#        0.34782615, 0.35272511, 0.35762407, 0.36252303, 0.36742199,
#        0.37232095, 0.37721991, 0.38211887, 0.38701783, 0.39191679,
#        0.39681575, 0.40171471, 0.40661367, 0.41151263, 0.41641159,
#        0.42131055, 0.42620951, 0.43110847, 0.43600743, 0.44090639,
#        0.44580535, 0.45070431, 0.45560327, 0.46050223, 0.46540119,
#        0.47030015, 0.47519911, 0.48009807, 0.48499703, 0.48989599,
#        0.49479495, 0.49969391, 0.50459287, 0.50949183, 0.51439079,
#        0.51928975, 0.52418871, 0.52908767, 0.53398663, 0.53888559,
#        0.54378455, 0.54868351, 0.55358247, 0.55848143, 0.56338039,
#        0.56827935, 0.57317831, 0.57807727, 0.58297623, 0.58787519,
#        0.59277415, 0.59767311, 0.60257207, 0.60747103, 0.61236999,
#        0.61726895, 0.62216791, 0.62706687, 0.63196583, 0.63686479,
#        0.64176375, 0.64666271, 0.65156167, 0.65646063, 0.66135959,
#        0.66625855, 0.6711575 , 0.67605646, 0.68095542, 0.68585438,
#        0.69075334, 0.6956523 , 0.70055126, 0.70545022, 0.71034918,
#        0.71524814, 0.7201471 , 0.72504606, 0.72994502, 0.73484398,
#        0.73974294, 0.7446419 , 0.74954086, 0.75443982, 0.75933878,
#        0.76423774, 0.7691367 , 0.77403566, 0.77893462, 0.78383358,
#        0.78873254, 0.7936315 , 0.79853046, 0.80342942, 0.80832838,
#        0.81322734, 0.8181263 , 0.82302526, 0.82792422, 0.83282318,
#        0.83772214, 0.8426211 , 0.84752006, 0.85241902, 0.85731798,
#        0.86221694, 0.8671159 , 0.87201486, 0.87691382, 0.88181278,
#        0.88671174, 0.8916107 , 0.89650966, 0.90140862, 0.90630758,
#        0.91120654, 0.9161055 , 0.92100446, 0.92590342, 0.93080238,
#        0.93570134, 0.9406003 , 0.94549926, 0.95039822, 0.95529718,
#        0.96019614, 0.9650951 , 0.96999406, 0.97489302, 0.97979198,
#        0.98469094, 0.9895899 , 0.99448886, 0.99938782, 1.00428678,
#        1.00918574, 1.0140847 , 1.01898366, 1.02388262, 1.02878158,
#        1.03368054, 1.0385795 , 1.04347846, 1.04837742, 1.05327638,
#        1.05817534, 1.0630743 , 1.06797326, 1.07287222, 1.07777118,
#        1.08267014, 1.0875691 , 1.09246806, 1.09736702, 1.10226598,
#        1.10716494, 1.11206389, 1.11696285, 1.12186181, 1.12676077,
#        1.13165973, 1.13655869, 1.14145765, 1.14635661, 1.15125557,
#        1.15615453, 1.16105349, 1.16595245, 1.17085141, 1.17575037,
#        1.18064933, 1.18554829, 1.19044725, 1.19534621, 1.20024517,
#        1.20514413, 1.21004309, 1.21494205, 1.21984101, 1.22473997,
#        1.21984101, 1.21494205, 1.21004309, 1.20514413, 1.20024517,
#        1.19534621, 1.19044725, 1.18554829, 1.18064933, 1.17575037,
#        1.17085141, 1.16595245, 1.16105349, 1.15615453, 1.15125557,
#        1.14635661, 1.14145765, 1.13655869, 1.13165973, 1.12676077,
#        1.12186181, 1.11696285, 1.11206389, 1.10716494, 1.10226598,
#        1.09736702, 1.09246806, 1.0875691 , 1.08267014, 1.07777118,
#        1.07287222, 1.06797326, 1.0630743 , 1.05817534, 1.05327638,
#        1.04837742, 1.04347846, 1.0385795 , 1.03368054, 1.02878158,
#        1.02388262, 1.01898366, 1.0140847 , 1.00918574, 1.00428678,
#        0.99938782, 0.99448886, 0.9895899 , 0.98469094, 0.97979198,
#        0.97489302, 0.96999406, 0.9650951 , 0.96019614, 0.95529718,
#        0.95039822, 0.94549926, 0.9406003 , 0.93570134, 0.93080238,
#        0.92590342, 0.92100446, 0.9161055 , 0.91120654, 0.90630758,
#        0.90140862, 0.89650966, 0.8916107 , 0.88671174, 0.88181278,
#        0.87691382, 0.87201486, 0.8671159 , 0.86221694, 0.85731798,
#        0.85241902, 0.84752006, 0.8426211 , 0.83772214, 0.83282318,
#        0.82792422, 0.82302526, 0.8181263 , 0.81322734, 0.80832838,
#        0.80342942, 0.79853046, 0.7936315 , 0.78873254, 0.78383358,
#        0.77893462, 0.77403566, 0.7691367 , 0.76423774, 0.75933878,
#        0.75443982, 0.74954086, 0.7446419 , 0.73974294, 0.73484398,
#        0.72994502, 0.72504606, 0.7201471 , 0.71524814, 0.71034918,
#        0.70545022, 0.70055126, 0.6956523 , 0.69075334, 0.68585438,
#        0.68095542, 0.67605646, 0.6711575 , 0.66625855, 0.66135959,
#        0.65646063, 0.65156167, 0.64666271, 0.64176375, 0.63686479,
#        0.63196583, 0.62706687, 0.62216791, 0.61726895, 0.61236999,
#        0.60747103, 0.60257207, 0.59767311, 0.59277415, 0.58787519,
#        0.58297623, 0.57807727, 0.57317831, 0.56827935, 0.56338039,
#        0.55848143, 0.55358247, 0.54868351, 0.54378455, 0.53888559,
#        0.53398663, 0.52908767, 0.52418871, 0.51928975, 0.51439079,
#        0.50949183, 0.50459287, 0.49969391, 0.49479495, 0.48989599,
#        0.48499703, 0.48009807, 0.47519911, 0.47030015, 0.46540119,
#        0.46050223, 0.45560327, 0.45070431, 0.44580535, 0.44090639,
#        0.43600743, 0.43110847, 0.42620951, 0.42131055, 0.41641159,
#        0.41151263, 0.40661367, 0.40171471, 0.39681575, 0.39191679,
#        0.38701783, 0.38211887, 0.37721991, 0.37232095, 0.36742199,
#        0.36252303, 0.35762407, 0.35272511, 0.34782615, 0.34292719,
#        0.33802823, 0.33312927, 0.32823031, 0.32333135, 0.31843239,
#        0.31353343, 0.30863447, 0.30373551, 0.29883655, 0.29393759,
#        0.28903863, 0.28413967, 0.27924071, 0.27434175, 0.26944279,
#        0.26454383, 0.25964487, 0.25474591, 0.24984695, 0.24494799,
#        0.24004903, 0.23515007, 0.23025111, 0.22535215, 0.2204532 ,
#        0.21555424, 0.21065528, 0.20575632, 0.20085736, 0.1959584 ,
#        0.19105944, 0.18616048, 0.18126152, 0.17636256, 0.1714636 ,
#        0.16656464, 0.16166568, 0.15676672, 0.15186776, 0.1469688 ,
#        0.14206984, 0.13717088, 0.13227192, 0.12737296, 0.122474  ,
#        0.11757504, 0.11267608, 0.10777712, 0.10287816, 0.0979792 ,
#        0.09308024, 0.08818128, 0.08328232, 0.07838336, 0.0734844 ,
#        0.06858544, 0.06368648, 0.05878752, 0.05388856, 0.0489896 ,
#        0.04409064, 0.03919168, 0.03429272, 0.02939376, 0.0244948 ,
#        0.01959584, 0.01469688, 0.00979792, 0.00489896])

# %% [markdown]
# As in the previous video, we can construct the Hamiltonian for this system and find the wavefunctions in Python. It turns out that this is just the kinetic energy which can be represented as a tridiagonal matrix.

# %%
#H

H = -hbar**2/(2*m) *1/(Delta_x)**2 * (np.diag(-2*np.ones(N-1))+ np.diag(np.ones(N-2),1)+ np.diag(np.ones(N-2),-1))

#diagonalise
E,psi = np.linalg.eigh(H)


norm = integral(psi.T**2)

psi = psi.T/np.sqrt(norm)

# %% [markdown]
# Now, we can find the expansion coefficients for $\Psi(x,t)$ by integrating with $\Psi(x,0)$.
# Once we have the $c_j$, we should make sure that they are normalised. Since $|c_j|^2$ represents the probability of finding the system in state $\psi_j$, we want:
#
# $$\sum_j |c_j|^2 =1$$

# %%
c = []

for n in range(N-1):
    
    c.append(integral(psi0(x[1:-1])*psi[n]))
             
             
c = np.array(c)
np.linalg.norm(c)
# Out:
# 1.0

# %% [markdown]
# With the $c_j$, we can construct the expansion for $\Psi(x,t)$ and plot this time-dependent wavefunction to see how it varies with time.

# %%
def Psi(t):
    
    return psi.T@(c*np.exp(-1j * E*t))

# %%
plt.plot(x[1:-1], Psi(20)**2)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# This is just an animation to see how the density evolves with time in the well.

# %%
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

fig = plt.figure(figsize = (10,8))
ax = plt.axes(xlim=[0,L],ylim=[-1,1])

line, = ax.plot(x[1:-1],np.zeros(N-1),lw=2,color="red")

def animate(t):
    
    y = np.imag(Psi(t))
    line.set_data(x[1:-1],y)  
    
    return (line,)


def init():
    line.set_data([],[])            
    return (line,)

ani = FuncAnimation(fig, animate, np.linspace(0.,5,250), init_func=init,
                              interval=100, blit=True)
HTML(ani.to_html5_video())
# Out:
# <video width="720" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...
